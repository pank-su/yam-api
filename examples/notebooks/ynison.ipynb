// %%
import su.pank.yamapi.builder.createYaMusicApiClient

val yamToken = System.getenv("YAM_TOKEN")!!

val client = createYaMusicApiClient {
    token = yamToken
}

// %%
@file:OptIn(ExperimentalYamApi::class)

import kotlinx.coroutines.runBlocking
import su.pank.yamapi.exceptions.ExperimentalYamApi
import su.pank.yamapi.ynison.ynison

runBlocking {
    client.ynison.connect()
}
// Out:
// PutYnisonStateResponse{player_state=PlayerState{status=PlayingStatus{progress_ms=12324, duration_ms=215435, paused=false, playback_speed=1.0, version=UpdateVersion{device_id=4d0209fffa76e0f91bd7b3b39712fa81, version=5515193906631970737, timestamp_ms=1763300454787, unknownFields=[]}, unknownFields=[]}, player_queue=PlayerQueue{entity_id=user:onyourwave, entity_type=RADIO, queue=Queue{type=Wave_queue(wave_queue=WaveQueue{recommended_playable_listList=[Playable{playable_id=42552214, album_id_optional=StringValue{value=5623068, unknownFields=[]}, playable_type=TRACK, from=radio-mobile-default, title=Fly Me to the Moon, cover_url_optional=StringValue{value=avatars.yandex.net/get-music-content/114728/bc38b9da.a.5623068-1/%%, unknownFields=[]}, additional_info_optional=Track_info(track_info=TrackInfo{track_source_key=0, batch_id_optional=StringValue{value=b9bf95c3-dd53-450e-9ec8-9e1133b87265.NHfr, unknownFields=[]}, unknownFields=[]}), unknownFields=[LengthDelimited(number=9, value=[10, 48
// ...
